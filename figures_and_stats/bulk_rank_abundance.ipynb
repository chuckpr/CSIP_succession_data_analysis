# %%
from IPython.display import FileLink

# %%
# %load_ext rpy2.ipython
# Out:
# /opt/anaconda/lib/python2.7/site-packages/pytz/__init__.py:29: UserWarning: Module argparse was already imported from /opt/anaconda/lib/python2.7/argparse.pyc, but /opt/anaconda/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
# %%R
# library(phyloseq)
# library(ggplot2)
# library(plyr)

# %%
# %%R
# physeq = import_biom("../data/otu_table_wtax.biom", "../data/otusn.tree")
# sample.data = import_qiime_sample_data("../data/ABCD_combined_reads_mapper.tsv")
# physeq = merge_phyloseq(physeq,sample.data)
# physeq.md = sample_data(physeq)
#
# physeq.PS.bulk = prune_samples((physeq.md$Treatment %in% c("12CCPS","13CCPS","13CXPS"))&
#                                (row.names(physeq.md) %in% grep("bulk", row.names(physeq.md), value=TRUE)), physeq)
# physeq.PS.bulk = transform_sample_counts(physeq.PS.bulk, function(x) x/sum(x))
# physeq.PS.bulk = filter_taxa(physeq.PS.bulk, function(x) sum(x > 0) > (0.25 * length(x)), TRUE)
#
# print(physeq.PS.bulk)
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1168 taxa and 12 samples ]
# sample_data() Sample Data:       [ 12 samples by 7 sample variables ]
# tax_table()   Taxonomy Table:    [ 1168 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 1168 tips and 1167 internal nodes ]

# %%
# %%R
# mdf = psmelt(physeq.PS.bulk)
# head(mdf)
# Out:
#      OTU         Sample Abundance     X.SampleID BarcodeSequence Day Density
# 1  OTU.1  13C.PS.7.bulk 0.1732970  13C.PS.7.bulk      TCAGCAGTAG   7      NA
# 10 OTU.1  13C.PS.3.bulk 0.1517008  13C.PS.3.bulk      TCAGCAGATG   3      NA
# 3  OTU.1 13C.PS.30.bulk 0.1197240 13C.PS.30.bulk      TCAGCATCCA  30      NA
# 9  OTU.1 13C.PS.14.bulk 0.1157386 13C.PS.14.bulk      TCAGCAGTTC  14      NA
# 5  OTU.1 cont.PS.1.bulk 0.1130890 cont.PS.1.bulk      TCAGAGGACT   1      NA
# 2  OTU.1  13X.PS.7.bulk 0.1068859  13X.PS.7.bulk      TCACTGACTG   7      NA
#      LinkerPrimerSequence Treatment    Description    Rank1          Rank2
# 1  CAGGACTACHVGGGTWTCTAAT    13CCPS  13C.PS.7.bulk Bacteria Actinobacteria
# 10 CAGGACTACHVGGGTWTCTAAT    13CCPS  13C.PS.3.bulk Bacteria Actinobacteria
# 3  CAGGACTACHVGGGTWTCTAAT    13CCPS 13C.PS.30.bulk Bacteria Actinobacteria
# 9  CAGGACTACHVGGGTWTCTAAT    13CCPS 13C.PS.14.bulk Bacteria Actinobacteria
# 5  CAGGACTACHVGGGTWTCTAAT    12CCPS cont.PS.1.bulk Bacteria Actinobacteria
# 2  CAGGACTACHVGGGTWTCTAAT    13CXPS  13X.PS.7.bulk Bacteria Actinobacteria
#            Rank3          Rank4        Rank5 Rank6 Rank7 Rank8
# 1  Micrococcales Micrococcaceae Arthrobacter  <NA>  <NA>  <NA>
# 10 Micrococcales Micrococcaceae Arthrobacter  <NA>  <NA>  <NA>
# 3  Micrococcales Micrococcaceae Arthrobacter  <NA>  <NA>  <NA>
# 9  Micrococcales Micrococcaceae Arthrobacter  <NA>  <NA>  <NA>
# 5  Micrococcales Micrococcaceae Arthrobacter  <NA>  <NA>  <NA>
# 2  Micrococcales Micrococcaceae Arthrobacter  <NA>  <NA>  <NA>

# %%
# %%R
# mdf.byday = ddply(mdf, .(Day, OTU), summarize, mean_day_abundance = mean(Abundance))
# mdf.byday = mdf.byday[order( mdf.byday$Day, -mdf.byday$mean_day_abundance),]
# mdf.1 = subset(mdf.byday, Day == 1)
# mdf.1$Rank = rank(-mdf.1$mean_day_abundance, ties.method = "random")
# mdf.byday.ranked = join(mdf.byday, mdf.1[,c("OTU","Rank")], by = "OTU")

# %%
# %%R -w 600 -h 350
#
# p = ggplot(mdf.byday.ranked, aes(x = Rank, y = mean_day_abundance, color = factor(Day)))
#
# p = p + geom_line(alpha = 0.5)
#
# p = p + geom_line(data = subset(mdf.byday.ranked, Day == 1), size = 2)
#
# p = p + scale_y_log10()
#
# p = p + scale_x_log10()
#
# p = p + theme_bw()
#
# p = p + labs(x = "Day 1 Rank", y = "Relative Abundance", color = "Day")
#
# p

# %%
# %%R
# ggsave("figs/RA_byday.pdf", p, h = 3.5, w = 6)

# %%
FileLink("figs/RA_byday.pdf")
# Out:
# /home/chuck/working/CSIP_succession_data_analysis/figures_and_stats/figs/RA_byday.pdf
