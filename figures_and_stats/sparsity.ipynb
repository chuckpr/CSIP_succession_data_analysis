# %%
# %load_ext rpy2.ipython
# Out:
# /opt/anaconda/lib/python2.7/site-packages/pytz/__init__.py:29: UserWarning: Module argparse was already imported from /opt/anaconda/lib/python2.7/argparse.pyc, but /opt/anaconda/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
# %%R
# library(phyloseq)
# library(dplyr)
# library(ggplot2)
# library(tidyr)

# %%
# %%R
#
# asNumeric = function(x) { as.numeric(as.character(x)) }
#
# physeq = import_biom("../data/otu_table_wtax.biom", "../data/otusn.tree")
# sample.data = import_qiime_sample_data("../data/ABCD_combined_reads_mapper.tsv")
# sample.data$Density = asNumeric(sample.data$Density)
#
# physeq = merge_phyloseq(physeq,sample.data)
#
# md = sample_data(physeq)
# physeq = prune_samples(!(row.names(md) %in% grep("bulk", row.names(md), value=TRUE)), physeq)
# physeq
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 6236 taxa and 337 samples ]
# sample_data() Sample Data:       [ 337 samples by 7 sample variables ]
# tax_table()   Taxonomy Table:    [ 6236 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 6236 tips and 6235 internal nodes ]

# %%
# %%R
# density.min = 1.7125
# density.max = 1.755
#
# md = sample_data(physeq)
# physeq.heavy = prune_samples((md$Density >= density.min)&
#                              (md$Density <= density.max), physeq)

# %%
# %%R
# mdf.all = psmelt(physeq)
# mdf.heavy = psmelt(physeq.heavy)
# mdf.all$type = "all"
# mdf.heavy$type = "heavy"
# mdf.cmb = rbind(mdf.all, mdf.heavy)

# %%
# %%R
# mdf.cmb$experiment = with(mdf.cmb, ifelse(Treatment %in% c("12CCPS", "13CXPS"), "xylose", "cellulose"))

# %%
# %%R
# sparsity.df = mdf.cmb %>%
#     group_by(OTU, Day, experiment, type) %>%
#     summarize(fraction_nonzeros = sum(Abundance > 0) / length(Abundance))
#
# sparsity.df
# Out:
# Source: local data frame [112,248 x 5]
# Groups: OTU, Day, experiment
#
#      OTU Day experiment  type fraction_nonzeros
# 1  OTU.1   1     xylose   all                 1
# 2  OTU.1   1     xylose heavy                 1
# 3  OTU.1   3  cellulose   all                 1
# 4  OTU.1   3  cellulose heavy                 1
# 5  OTU.1   3     xylose   all                 1
# 6  OTU.1   3     xylose heavy                 1
# 7  OTU.1   7  cellulose   all                 1
# 8  OTU.1   7  cellulose heavy                 1
# 9  OTU.1   7     xylose   all                 1
# 10 OTU.1   7     xylose heavy                 1
# ..   ... ...        ...   ...               ...

# %%
# %%R -w 550 -h 450
# d = sparsity.df %>% filter(fraction_nonzeros > 0) %>% group_by(add = FALSE) %>% spread(type, fraction_nonzeros)
#
# p = ggplot(d, aes(x = all, y = heavy))
#
# p = p + geom_point(size = 3, alpha = 0.15, position = position_jitter(h = 0.025, w = 0.025))
#
# p = p + geom_hline(y = 0.60, size = 1.5, color = "red")
#
# p = p + theme_bw()
#
# p = p + theme(axis.text = element_text(size = 14),
#               axis.title = element_text(size = 16))
#
# p

# %%
# %%R
# d
# Out:
# Source: local data frame [35,390 x 5]
#
#       OTU Day experiment all heavy
# 1   OTU.1   1     xylose   1     1
# 2   OTU.1   3  cellulose   1     1
# 3   OTU.1   3     xylose   1     1
# 4   OTU.1   7  cellulose   1     1
# 5   OTU.1   7     xylose   1     1
# 6   OTU.1  14  cellulose   1     1
# 7   OTU.1  14     xylose   1     1
# 8   OTU.1  30  cellulose   1     1
# 9   OTU.1  30     xylose   1     1
# 10 OTU.10   1     xylose   1     1
# ..    ... ...        ... ...   ...

# %%
# %%R
# fit = lm(heavy ~ all, d)
# summary(fit)
# Out:
# Call:
# lm(formula = heavy ~ all, data = d)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.37870 -0.03616  0.00379  0.03776  0.54438
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.0152211  0.0006624   22.98   <2e-16 ***
# all         0.9786620  0.0018344  533.51   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0769 on 26436 degrees of freedom
#   (8952 observations deleted due to missingness)
# Multiple R-squared:  0.915,	Adjusted R-squared:  0.915
# F-statistic: 2.846e+05 on 1 and 26436 DF,  p-value: < 2.2e-16

# %%
# %%R -w 800 -h 350
# p = ggplot(sparsity.df %>% filter(fraction_nonzeros > 0), aes(x = fraction_nonzeros))
# #p = ggplot(sparsity.df, aes(x = sparsity))
#
# p = p + geom_histogram(binwidth = 0.06)
#
# p = p + facet_wrap(~type)
#
# p = p + theme_bw()
#
# p = p + theme(strip.text = element_text(size = 16),
#               strip.background = element_blank(),
#               axis.text = element_text(size = 16),
#               axis.title = element_text(size = 16))
#
# p

# %%
# %%R
#
# asNumeric = function(x) { as.numeric(as.character(x)) }
#
# p = import_biom("../data/otu_table_wtax.biom", "../data/otusn.tree")
# sample.data = import_qiime_sample_data("../data/ABCD_combined_reads_mapper.tsv")
# sample.data$Density = asNumeric(sample.data$Density)
#
# p = merge_phyloseq(p,sample.data)
#
# md = sample_data(p)
# physeq.bulk = prune_samples((row.names(md) %in% grep("bulk", row.names(md), value=TRUE)), p)
# physeq.bulk
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 6236 taxa and 15 samples ]
# sample_data() Sample Data:       [ 15 samples by 7 sample variables ]
# tax_table()   Taxonomy Table:    [ 6236 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 6236 tips and 6235 internal nodes ]

# %%
# %%R
# mdf.bulk = psmelt(physeq.bulk)

# %%
# %%R
# mdf.bulk$experiment = with(mdf.bulk, ifelse(Treatment %in% c("12CCPS", "13CXPS"), "xylose", "cellulose"))
# mdf.bulk = mdf.bulk %>%
#     group_by(Sample) %>%
#     mutate(A.rel = Abundance / sum(Abundance))

# %%
# %%R -w 1000
# d = left_join(mdf.bulk, sparsity.df) %>% select(OTU, Day, Treatment, A.rel, type, fraction_nonzeros, Rank2)
#
# p = ggplot(d, aes(y = A.rel, x = fraction_nonzeros))
#
# p = p + geom_point(size = 4, alpha = 0.1, shape = 20, position = position_jitter(w = 0.02))
#
# p = p + facet_wrap(~type)
#
# p = p + scale_y_log10()
#
# p = p + geom_vline(x = 0.6, size = 1.5, color = "red")
#
# p = p + theme_bw()
#
# p = p + theme(strip.text = element_text(size = 16),
#               strip.background = element_blank(),
#               axis.text = element_text(size = 16),
#               axis.title = element_text(size = 16))
#
# p
# Out:
# Joining by: c("OTU", "Day", "experiment")

# %%
# %%R
# d.bulk = mdf.bulk %>%
#     group_by(Sample) %>%
#     mutate(R = rank(desc(Abundance))) %>%
#     select(Sample, R, OTU, Day, Treatment, Abundance) %>%
#     group_by()
#
# d.bulk
# Out:
# Source: local data frame [93,540 x 6]
#
#             Sample R   OTU Day Treatment Abundance
# 1    13C.PS.3.bulk 1 OTU.1   3    13CCPS       718
# 2    13C.PS.7.bulk 1 OTU.1   7    13CCPS       636
# 3    13X.PS.7.bulk 1 OTU.1   7    13CXPS       520
# 4   13C.PS.14.bulk 1 OTU.1  14    13CCPS       503
# 5    13X.PS.3.bulk 1 OTU.1   3    13CXPS       398
# 6   cont.PS.3.bulk 1 OTU.1   3    12CCPS       332
# 7   cont.PS.1.bulk 1 OTU.1   1    12CCPS       324
# 8    13X.PS.1.bulk 1 OTU.1   1    13CXPS       321
# 9  cont.PS.30.bulk 1 OTU.1  30    12CCPS       319
# 10  13X.PS.14.bulk 1 OTU.1  14    13CXPS       296
# ..             ... .   ... ...       ...       ...

# %%
# %%R
# sample.sparsity = mdf.cmb %>%
#     group_by(OTU, Day, Treatment, type) %>%
#     summarize(fraction_nonzeros = sum(Abundance > 0) / length(Abundance))
#
# sample.sparsity
# Out:
# Source: local data frame [212,024 x 5]
# Groups: OTU, Day, Treatment
#
#      OTU Day Treatment  type fraction_nonzeros
# 1  OTU.1   1    12CCPS   all                 1
# 2  OTU.1   1    12CCPS heavy                 1
# 3  OTU.1   1    13CXPS   all                 1
# 4  OTU.1   1    13CXPS heavy                 1
# 5  OTU.1   3    12CCPS   all                 1
# 6  OTU.1   3    12CCPS heavy                 1
# 7  OTU.1   3    13CCPS   all                 1
# 8  OTU.1   3    13CCPS heavy                 1
# 9  OTU.1   3    13CXPS   all                 1
# 10 OTU.1   3    13CXPS heavy                 1
# ..   ... ...       ...   ...               ...

# %%
# %%R -w 1200 -h 900
# d = left_join(d.bulk, sample.sparsity) %>% filter(type == "all")
#
# p = ggplot(d, aes(x = R, y = Abundance, color = fraction_nonzeros))
#
# p = p + facet_wrap(~Sample, scales = "free_y")
#
# p = p + geom_line(size = 1, color = "gray")
#
# p = p + geom_point(size = 4, shape = 21)
#
# p = p + scale_y_log10()
#
# p = p + scale_x_log10()
#
# p = p + scale_color_gradientn(colours = rev(rainbow(3)))
#
# p = p + theme_bw()
#
# p = p + theme(strip.text = element_text(size = 16),
#               strip.background = element_blank(),
#               axis.text = element_text(size = 16),
#               axis.title = element_text(size = 16),
#               panel.border = element_rect(size = 2))
#
# p
# Out:
# Joining by: c("OTU", "Day", "Treatment")
