# %%
import pandas as pd
import pandas.rpy.common as com
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import brewer2mpl
from mpltools import style
from IPython.display import FileLink
style.use("ggplot")
# %matplotlib inline
# Out:
# /opt/anaconda/lib/python2.7/site-packages/pytz/__init__.py:29: UserWarning: Module argparse was already imported from /opt/anaconda/lib/python2.7/argparse.pyc, but /opt/anaconda/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
df_all = pd.read_csv("../data/l2fc.csv", sep=",")
df_all["logP"] = [-np.log(p) for p in df_all["p.adj"]]
df_pivot = df_all.pivot_table(rows="OTU", cols=["Treatment","Day"], values="logP")

OTU_series = df_all.groupby("OTU").first()["Rank2"]
df_pivot = df_pivot.join(OTU_series)

phyla = df_all.sort("log2FoldChange").groupby("Rank2").last()
phyla.sort("log2FoldChange", ascending=False, inplace=True)

xd = dict([(p, x + 1) for x, p in enumerate(phyla.index.tolist())])
xmax = np.max(xd.values()) + 1
X = []
for p in df_pivot.Rank2:
    try:
        X.append(xd[p])
    except KeyError:
        X.append(xmax)
df_pivot["X"] = X

m1 = brewer2mpl.get_map("Paired", "qualitative", 8)
m2 = brewer2mpl.get_map("Dark2", "qualitative", 8)
colors = m1.hex_colors + m2.hex_colors
cd = dict(zip(phyla.index.tolist(), colors))
phylum_color = []
for p in df_pivot.Rank2:
    try:
        phylum_color.append(cd[p])
    except KeyError:
        phylum_color.append("#151515")
df_pivot["phylum_color"] = phylum_color

# %%
df = df_pivot

matplotlib.rcParams["axes.facecolor"] = "white"
matplotlib.rcParams["axes.edgecolor"] = "#151515"
matplotlib.rcParams["grid.color"] = "#F5F5F5"
matplotlib.rcParams["grid.alpha"] = "0.75"

thresh = 0.75

fig = plt.figure()
fig.set_size_inches(12,7)

gs = gridspec.GridSpec(nrows = 2, ncols = 6, width_ratios=[1,1,1,1,1,0.5], 
                       left=0.05, right=0.95, bottom=0.05, top=0.95,
                       hspace=0.1, wspace=0.05)

N = len(phyla.index) + 1
treatment = ["13CCPS", "13CXPS"]
days = [1,3,7,14,30]
ncol = 5
nrow = 2
for j, d in zip(range(ncol), days):
    for i, t in zip(range(nrow), treatment):
        try:
            ax = fig.add_subplot(gs[i,j])
            points = ax.scatter(df.X + 0.45 * np.random.random(len(df.X)),
                                df[(t,d)], alpha = 1.00, c = df.phylum_color.tolist(), 
                                s = 20, linewidth=0.25, edgecolor = "#505050")
            ax.axhline(thresh, color = "#151515")
            ax.set_title("%s %s"%(t, d))
        except KeyError:
            ax.set_visible(False)
            continue

axs = fig.get_axes()
xmin = np.array([axi.get_xlim()[0] for axi in axs]).min()
xmax = np.array([axi.get_xlim()[1] for axi in axs]).max()
ymin = np.array([axi.get_ylim()[0] for axi in axs]).min()
ymax = np.array([axi.get_ylim()[1] for axi in axs]).max()            

for axi in axs:
    axi.set_xlim([xmin,xmax])

for i, axi in enumerate(axs):
    axi.set_ylim([ymin,ymax])
    axi.set_xticks(np.arange(N) + 1)
    axi.set_xticklabels([])
    axi.set_xlim([0, N+1])
    
for axi in axs[3:]:
    axi.set_yticklabels([])

fig.text(0.005, 0.5, r"$-Log($ adjusted p value $)$", rotation="vertical", va ="center", fontsize=16)
fig.text(0.45, 0, "Phylum", fontsize=16)

dummy_lines = []
for p in phyla.index.tolist():
    l, = axs[0].plot([1],[1], "o", color = cd[p], label = p)
    dummy_lines.append(l)

leg = fig.legend(dummy_lines, phyla.index.tolist(), "upper left", ncol=1, numpoints=1, 
           bbox_to_anchor=(0.035, 1.02), frameon = False, prop = {"size":8, "style":"italic"})

leg.set_title("Phylum")

# %%
fig.savefig("../figs/manhattan.png", bbox_inches = "tight", dpi = 500)
FileLink("../figs/manhattan.png")
# Out:
# /home/chuck/working/succ-C-DNASIP/figs/manhattan.png

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['colors']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
H = hist(df_all["p.adj"], bins = 1000)
xlim(0, 0.1)
ylim(0,100)
# Out:
# (0, 100)

# %%
H = hist(df_all["p"], bins = 1000)
xlim(0, 0.0001)
ylim(0,100)
# Out:
# (0, 100)

# %%
df_all.sort("p")["p"]
# Out:
# 1942    3.496501e-23
# 2225    6.735315e-17
# 1944    4.234150e-15
# 3159    2.656979e-14
# 1959    9.496523e-14
# 3119    2.372982e-13
# 2319    7.764936e-12
# 2312    9.597166e-12
# 2320    2.041896e-11
# 1941    2.059534e-11
# 1954    8.294274e-11
# 1267    8.328981e-11
# 3303    4.218841e-10
# 1231    4.573433e-10
# 1283    6.902698e-10
# ...
# 632     1
# 2223    1
# 3529    1
# 3793    1
# 1501    1
# 2625    1
# 1271    1
# 1503    1
# 2485    1
# 2058    1
# 2729    1
# 3707    1
# 2105    1
# 303     1
# 2234    1
# Name: p, Length: 3825, dtype: float64

# %%
df_all.sort("p.adj")["p.adj"]
# Out:
# 1942    1.337412e-19
# 2225    1.288129e-13
# 1944    5.398541e-12
# 3159    2.540736e-11
# 1959    7.264840e-11
# 3119    1.512776e-10
# 2319    4.242983e-09
# 2312    4.588645e-09
# 2320    7.877718e-09
# 1941    7.877718e-09
# 1954    2.654863e-08
# 1267    2.654863e-08
# 3303    1.241313e-07
# 1231    1.249527e-07
# 1283    1.760188e-07
# ...
# 1275    1
# 1277    1
# 1278    1
# 1279    1
# 1280    1
# 1281    1
# 1282    1
# 1285    1
# 1286    1
# 1287    1
# 1288    1
# 1289    1
# 1290    1
# 1276    1
# 3824    1
# Name: p.adj, Length: 3825, dtype: float64
