# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
from IPython.display import FileLink

# %%
# %%R
# library(ggplot2)

# %%
# %%R
# df.l2fc = read.table("../data/l2fc_table.csv", sep=",", header = TRUE)
# head(df.l2fc)
# Out:
#   Sparsity_threshold Day Treatment     OTU log2FoldChange         p    Rank1
# 1                0.5   3    13CCPS  OTU.79     0.97788881 0.3076439 Bacteria
# 2                0.5   3    13CCPS  OTU.50     1.17798083 0.1838358 Bacteria
# 3                0.5   3    13CCPS OTU.162    -0.22691269 0.9513845 Bacteria
# 4                0.5   3    13CCPS OTU.156     0.60455350 0.5962004 Bacteria
# 5                0.5   3    13CCPS  OTU.12     1.28760171 0.1017773 Bacteria
# 6                0.5   3    13CCPS OTU.122    -0.03533796 0.9180021 Bacteria
#           Rank2            Rank3              Rank4            Rank5
# 1 Bacteroidetes       Cytophagia       Cytophagales    Cytophagaceae
# 2 Bacteroidetes       Cytophagia       Cytophagales    Cytophagaceae
# 3 Bacteroidetes       Cytophagia       Cytophagales    Cytophagaceae
# 4 Bacteroidetes       Cytophagia       Cytophagales    Cytophagaceae
# 5 Bacteroidetes Sphingobacteriia Sphingobacteriales Chitinophagaceae
# ...

# %%
# %%R
# unique(df.l2fc$Treatment)
# Out:
# [1] 13CCPS 13CXPS
# Levels: 13CCPS 13CXPS

# %%
# %%R -w 800 -h 600
#
# FDR = 0.10
#
# colors = c("#377eb8","#4daf4a")
#
# p = ggplot(df.l2fc, aes(x = log2FoldChange))
#
# p = p + facet_wrap(~Rank2)
#
# p = p + geom_density()
#
# p = p + geom_rug()
#
# p = p + geom_rug(data = subset(df.l2fc, (padj < FDR)),
#                  aes(color = Treatment), size = 1)
#
# p = p + scale_color_manual(values = colors)
#
# p = p + theme_bw()
#
# p = p + theme(strip.text = element_text(size = 12, face = "italic"),
#               strip.background = element_blank(),
#               axis.text = element_text(size = 12),
#               axis.title = element_text(size = 14),
#               legend.text = element_text(size = 14),
#               legend.title = element_text(size = 14))
#
# p = p + labs(x = expression(paste(Log[2], " Fold Change")),
#              y = "Kernel Density",
#              color = "Treatment")
#
# p
# Out:
# Error in eval(expr, envir, enclos) : object 'treatment' not found

# %%
# %%R
# ggsave("figs/l2fc_KDE.pdf", p, h = 12, w = 16)

# %%
FileLink("figs/l2fc_KDE.pdf")
# Out:
# /home/chuck/working/CSIP_succession_data_analysis/figures_and_stats/figs/l2fc_KDE.pdf
