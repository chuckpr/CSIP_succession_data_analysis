# %%
from IPython.display import FileLink

# %%
# %load_ext hierarchymagic
# Out:
# The hierarchymagic extension is already loaded. To reload it, use:
#   %reload_ext hierarchymagic

# %%
# %%dot -f svg
# digraph {
#
#     node [fontname = "helvetica"];
#     edge [fontname = "helvetica", penwidth=2];
#
#     subgraph cluster1 {
#         node [style=filled,color=white];
#         color = blue;
#         style=filled;
#         fillcolor=lightgray;
#         penwidth=2;
#         c; e; f;
#     }
#
#     subgraph cluster2 {
#         node [style=filled,color=white];
#         color = green;
#         style=filled;
#         fillcolor=lightgray;
#         penwidth=2;
#         d; g;
#     }
#
#     a->b [label="yes",fontsize=12,penwidth=2];
#     a->h [color=gray,label="no",fontcolor=gray];
#     b->c [color=blue,label="yes",fontcolor=blue];
#     b->d [color=green,label="no",fontcolor=green];
#     c->h [color=gray,label="no",fontcolor=gray];
#     c->e [color=blue,label="yes",fontcolor=blue];
#     d->g [color=green,label="yes",fontcolor=green];
#     e->h [color=gray,label="no",fontcolor=gray];
#     d->h [color=gray,label="no",fontcolor=gray];
#     e->f [color=blue,label="yes",fontcolor=blue];
#
#     a [shape=diamond,label="Significant\nInfo\nfor OTU?",fontsize=12];
#     b [shape=diamond,label=<Log<SUB>2</SUB> change &gt; theta?>,fontsize=12];
#     c [shape=diamond,label="mass shift > 0?",fontsize=12];
#     d [shape=diamond,label="Reject null\nhypothesis?",fontsize=12];
#     e [shape=diamond,label="Reject null\nhypothesis?",fontsize=12];
#     f [shape=doublecircle,style=filled,label="responder",fillcolor="#0000FF50",fontsize=16];
#     g [shape=doublecircle,style=filled,label="non-\nresponder",fillcolor="#00660050",fontsize=16];
#     h [shape=doublecircle,style=filled,label="response\nunknown",fillcolor="#05050520",fontsize=16];
# }

# %%
# %%dot -f svg -- -o figs/OTU_screening_schematic.svg
# digraph {
#
#     node [fontname = "helvetica"];
#     edge [fontname = "helvetica", penwidth=2];
#
#     subgraph cluster1 {
#         node [style=filled,color=white];
#         color = blue;
#         style=filled;
#         fillcolor=lightgray;
#         penwidth=2;
#         c; e; f;
#     }
#
#     subgraph cluster2 {
#         node [style=filled,color=white];
#         color = green;
#         style=filled;
#         fillcolor=lightgray;
#         penwidth=2;
#         d; g;
#     }
#
#     a->b [label="yes",fontsize=12,penwidth=2];
#     a->h [color=gray,label="no",fontcolor=gray];
#     b->c [color=blue,label="yes",fontcolor=blue];
#     b->d [color=green,label="no",fontcolor=green];
#     c->h [color=gray,label="no",fontcolor=gray];
#     c->e [color=blue,label="yes",fontcolor=blue];
#     d->g [color=green,label="yes",fontcolor=green];
#     e->h [color=gray,label="no",fontcolor=gray];
#     d->h [color=gray,label="no",fontcolor=gray];
#     e->f [color=blue,label="yes",fontcolor=blue];
#
#     a [shape=diamond,label="Significant\nInfo\nfor OTU?",fontsize=12];
#     b [shape=diamond,label=<Log<SUB>2</SUB> change &gt; theta?>,fontsize=12];
#     c [shape=diamond,label="mass shift > 0?",fontsize=12];
#     d [shape=diamond,label="Reject null\nhypothesis?",fontsize=12];
#     e [shape=diamond,label="Reject null\nhypothesis?",fontsize=12];
#     f [shape=doublecircle,style=filled,label="responder",fillcolor="#0000FF50",fontsize=16];
#     g [shape=doublecircle,style=filled,label="non-\nresponder",fillcolor="#00660050",fontsize=16];
#     h [shape=doublecircle,style=filled,label="response\nunknown",fillcolor="#05050520",fontsize=16];
# }

# %%
FileLink("figs/OTU_screening_schematic.svg")
# Out:
# /home/chuck/working/succ-C-DNASIP/figs/OTU_screening_schematic.svg
